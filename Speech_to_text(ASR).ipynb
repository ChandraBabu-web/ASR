# %%
#!pip install jedi==0.10
#https://github.com/NVIDIA/NeMo/blob/main/tutorials/asr/ASR_with_NeMo.ipynb

# %%
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.13.1+cu113)
# Requirement already satisfied: torch==1.12.1 in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.12.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (9.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchvision) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2022.9.24)

# %%
#!pip install torchtext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchtext in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext) (2.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.21.6)
# Collecting torch==1.9.0
#   Using cached torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchtext) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2.1.1)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.9.0 which is incompatible.
# Successfully installed torch-1.9.0

# %%
# !pip install Jinja2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.7/dist-packages (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /usr/local/lib/python3.7/dist-packages (from Jinja2) (2.0.1)

# %%
#1
# !pip install git+https://github.com/PyTorchLightning/pytorch-lightning
import pytorch_lightning as pl
print(pl.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/PyTorchLightning/pytorch-lightning
#   Cloning https://github.com/PyTorchLightning/pytorch-lightning to /tmp/pip-req-build-g2uqhkjn
#   Running command git clone -q https://github.com/PyTorchLightning/pytorch-lightning /tmp/pip-req-build-g2uqhkjn
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: torch>=1.10.* in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (1.12.1+cu113)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (2022.11.0)
# Collecting lightning-api-access>=0.0.1
#   Downloading lightning_api_access-0.0.1-py3-none-any.whl (888 kB)
#      |████████████████████████████████| 888 kB 36.2 MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (8.0.2)
# Collecting starsessions<2.0,>=1.2.1
#   Downloading starsessions-1.3.0-py3-none-any.whl (10 kB)
# Collecting arrow>=1.2.0
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 6.3 MB/s
# Collecting deepdiff>=5.7.0
#   Downloading deepdiff-6.2.1-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.1 MB/s
# Collecting lightning-utilities==0.3.*
#   Downloading lightning_utilities-0.3.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (0.10.3)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (4.64.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (21.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (1.21.6)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 70.7 MB/s
# Collecting traitlets>=5.3.0
#   Downloading traitlets-5.5.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 78.6 MB/s
# Collecting inquirer>=2.10.0
#   Downloading inquirer-2.10.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (4.1.1)
# Collecting croniter<1.4.0,>=1.3.0
#   Downloading croniter-1.3.8-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (5.4.8)
# Collecting beautifulsoup4>=4.8.0
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 74.6 MB/s
# Collecting lightning-cloud>=0.5.11
#   Downloading lightning_cloud-0.5.11-py3-none-any.whl (359 kB)
#      |████████████████████████████████| 359 kB 74.8 MB/s
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.7/dist-packages (from lightning==1.9.0.dev0) (5.4.1)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 8.4 MB/s
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from arrow>=1.2.0->lightning==1.9.0.dev0) (2.8.2)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting ordered-set<4.2.0,>=4.0.2
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.7/dist-packages (from fsspec>=2022.5.0->lightning==1.9.0.dev0) (3.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec>=2022.5.0->lightning==1.9.0.dev0) (2.23.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2022.5.0->lightning==1.9.0.dev0) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2022.5.0->lightning==1.9.0.dev0) (1.8.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2022.5.0->lightning==1.9.0.dev0) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2022.5.0->lightning==1.9.0.dev0) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2022.5.0->lightning==1.9.0.dev0) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2022.5.0->lightning==1.9.0.dev0) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2022.5.0->lightning==1.9.0.dev0) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2022.5.0->lightning==1.9.0.dev0) (4.0.2)
# Collecting python-editor>=1.0.4
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting blessed>=1.19.0
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.4 MB/s
# Collecting readchar>=3.0.6
#   Downloading readchar-4.0.3-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.19.0->inquirer>=2.10.0->lightning==1.9.0.dev0) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.19.0->inquirer>=2.10.0->lightning==1.9.0.dev0) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (1.25.11)
# Collecting websocket-client
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.0 MB/s
# Collecting pyjwt
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting fastapi[all]
#   Downloading fastapi-0.87.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.9 MB/s
# Requirement already satisfied: rich in /usr/local/lib/python3.7/dist-packages (from lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (12.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->lightning==1.9.0.dev0) (3.0.9)
# Requirement already satisfied: setuptools>=41.0 in /usr/local/lib/python3.7/dist-packages (from readchar>=3.0.6->inquirer>=2.10.0->lightning==1.9.0.dev0) (59.5.0)
# Collecting starlette<1,>=0
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.9 MB/s
# Requirement already satisfied: itsdangerous<3.0.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from starsessions<2.0,>=1.2.1->lightning==1.9.0.dev0) (2.1.2)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 11.0 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<5,>=3.4.0->starlette<1,>=0->starsessions<2.0,>=1.2.1->lightning==1.9.0.dev0) (2.10)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX>=2.2->lightning==1.9.0.dev0) (3.19.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click->lightning==1.9.0.dev0) (4.13.0)
# Collecting starlette<1,>=0
#   Downloading starlette-0.21.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.6 MB/s
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from fastapi[all]->lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (1.10.2)
# Collecting orjson>=3.2.1
#   Downloading orjson-3.8.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#      |████████████████████████████████| 278 kB 72.6 MB/s
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.7/dist-packages (from fastapi[all]->lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (3.0.0)
# Collecting python-multipart>=0.0.5
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Collecting email-validator>=1.1.1
#   Downloading email_validator-1.3.0-py2.py3-none-any.whl (22 kB)
# Collecting httpx>=0.23.0
#   Downloading httpx-0.23.1-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 4.3 MB/s
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1
#   Downloading ujson-5.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (45 kB)
#      |████████████████████████████████| 45 kB 4.6 MB/s
# Collecting uvicorn[standard]>=0.12.0
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 6.4 MB/s
# Requirement already satisfied: dnspython>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from email-validator>=1.1.1->fastapi[all]->lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (2.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx>=0.23.0->fastapi[all]->lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (2022.9.24)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.1-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 7.9 MB/s
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.4 MB/s
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.11.2->fastapi[all]->lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (2.1.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.17.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 59.2 MB/s
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.18.1-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 52.7 MB/s
# Collecting httptools>=0.5.0
#   Downloading httptools-0.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (404 kB)
#      |████████████████████████████████| 404 kB 75.8 MB/s
# Collecting websockets>=10.4
#   Downloading websockets-10.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 65.4 MB/s
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire->lightning-utilities==0.3.*->lightning==1.9.0.dev0) (2.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click->lightning==1.9.0.dev0) (3.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec>=2022.5.0->lightning==1.9.0.dev0) (3.0.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich->lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich->lightning-cloud>=0.5.11->lightning==1.9.0.dev0) (2.13.0)
# Building wheels for collected packages: lightning, python-multipart, fire
#   Building wheel for lightning (PEP 517) ... done
#   Created wheel for lightning: filename=lightning-1.9.0.dev0-py3-none-any.whl size=1710035 sha256=8dc00b31d85530c0ec7a1e3bea748ccb38dfd73807d710edbd000980a980b509
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rm3qjvya/wheels/18/24/dd/8e13b7dfcda990eb2b099a57bb6d705f6d43fb53ecb4ed07bf
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=8b436888914b213457f74222709c29889641cdee7a835a45c110f045d3fb50e8
#   Stored in directory: /root/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=d422b3eaedc9a1855a09c9ce1acc23840c3197ac06bc6446ec931dcbd0d92090
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built lightning python-multipart fire
# Installing collected packages: sniffio, rfc3986, h11, anyio, websockets, watchfiles, uvloop, uvicorn, starlette, python-dotenv, httptools, httpcore, ujson, python-multipart, orjson, httpx, fastapi, email-validator, websocket-client, soupsieve, readchar, python-editor, pyjwt, ordered-set, fire, blessed, traitlets, tensorboardX, starsessions, lightning-utilities, lightning-cloud, lightning-api-access, inquirer, deepdiff, croniter, beautifulsoup4, arrow, lightning
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed anyio-3.6.2 arrow-1.2.3 beautifulsoup4-4.11.1 blessed-1.19.1 croniter-1.3.8 deepdiff-6.2.1 email-validator-1.3.0 fastapi-0.87.0 fire-0.4.0 h11-0.14.0 httpcore-0.16.1 httptools-0.5.0 httpx-0.23.1 inquirer-2.10.1 lightning-1.9.0.dev0 lightning-api-access-0.0.1 lightning-cloud-0.5.11 lightning-utilities-0.3.0 ordered-set-4.1.0 orjson-3.8.2 pyjwt-2.6.0 python-dotenv-0.21.0 python-editor-1.0.4 python-multipart-0.0.5 readchar-4.0.3 rfc3986-1.5.0 sniffio-1.3.0 soupsieve-2.3.2.post1 starlette-0.21.0 starsessions-1.3.0 tensorboardX-2.5.1 traitlets-5.5.0 ujson-5.5.0 uvicorn-0.20.0 uvloop-0.17.0 watchfiles-0.18.1 websocket-client-1.4.2 websockets-10.4
# 1.7.7

# %%
BRANCH = 'r1.7.0' 
#2
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision r1.7.0) to /tmp/pip-install-p3so9vws/nemo-toolkit_3ecbc4043cb84df3b4d41ae08c4caaac
#   Running command git clone -q https://github.com/NVIDIA/NeMo.git /tmp/pip-install-p3so9vws/nemo-toolkit_3ecbc4043cb84df3b4d41ae08c4caaac
#   Running command git checkout -b r1.7.0 --track origin/r1.7.0
#   Switched to a new branch 'r1.7.0'
#   Branch 'r1.7.0' set up to track remote branch 'r1.7.0' from 'origin'.
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.21.6)
# Collecting onnx>=1.7.0
#   Downloading onnx-1.12.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 32.4 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.12.1+cu113)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.14.1)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 72.7 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.64.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.56.4)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Collecting frozendict
#   Downloading frozendict-2.3.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (99 kB)
#      |████████████████████████████████| 99 kB 10.4 MB/s
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 71.5 MB/s
# Collecting black==19.10b0
#   Downloading black-19.10b0-py36-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 7.7 MB/s
# Collecting isort[requirements]<5
#   Downloading isort-4.3.21-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.2 MB/s
# Collecting parameterized
#   Downloading parameterized-0.8.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.6.4)
# Collecting pytest-runner
#   Using cached pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.8.6)
# Collecting sphinxcontrib-bibtex
#   Downloading sphinxcontrib_bibtex-2.5.0-py3-none-any.whl (39 kB)
# Collecting wandb
#   Downloading wandb-0.13.5-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 63.7 MB/s
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2022.6.2)
# Collecting pytorch-lightning==1.5.10
#   Downloading pytorch_lightning-1.5.10-py3-none-any.whl (527 kB)
#      |████████████████████████████████| 527 kB 71.0 MB/s
# Collecting torchmetrics>=0.4.1rc0
#   Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#      |████████████████████████████████| 529 kB 73.0 MB/s
# Collecting transformers>=4.0.1
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 69.3 MB/s
# Collecting webdataset<=0.1.62,>=0.1.48
#   Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Collecting omegaconf>=2.1.0
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.5 MB/s
# Collecting hydra-core>=1.1.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 69.0 MB/s
# Collecting pyyaml<6
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 64.3 MB/s
# Collecting sentencepiece<1.0.0
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 63.1 MB/s
# Collecting youtokentome>=1.0.5
#   Downloading youtokentome-1.0.6-cp37-cp37m-manylinux2010_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 63.4 MB/s
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.5.3)
# Collecting kaldi-io
#   Downloading kaldi_io-0.9.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: marshmallow in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.19.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (21.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.11.0)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting kaldi-python-io
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
# Collecting kaldiio
#   Downloading kaldiio-2.17.2.tar.gz (24 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3.5)
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 57.7 MB/s
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting pyannote.core
#   Downloading pyannote.core-4.5-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 8.5 MB/s
# Collecting pyannote.metrics
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 207 kB/s
# Collecting torch-stft
#   Downloading torch_stft-0.1.4-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.13.1+cu113)
# Collecting boto3
#   Downloading boto3-1.26.14-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 59.6 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.1.0)
# Collecting matplotlib>=3.3.2
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 53.4 MB/s
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 50.0 MB/s
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.4.0)
# Collecting sacrebleu[ja]
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 78.0 MB/s
# Collecting sacremoses>=0.0.43
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 71.6 MB/s
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.7)
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 7.4 MB/s
# Collecting opencc
#   Downloading OpenCC-1.1.4-cp37-cp37m-manylinux1_x86_64.whl (769 kB)
#      |████████████████████████████████| 769 kB 66.0 MB/s
# Collecting pangu
#   Downloading pangu-4.0.6.1-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: jieba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.42.1)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.6 MB/s
# Collecting pypinyin
#   Downloading pypinyin-0.47.1-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 60.1 MB/s
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting pystoi
#   Downloading pystoi-0.3.3.tar.gz (7.0 kB)
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (22.1.0)
# Collecting pathspec<1,>=0.6
#   Downloading pathspec-0.10.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: click>=6.5 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (7.1.2)
# Collecting typed-ast>=1.4.0
#   Downloading typed_ast-1.5.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 61.4 MB/s
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 43.2 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->nemo_toolkit[all]) (2.9.1)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 68.0 MB/s
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->nemo_toolkit[all]) (4.1.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->nemo_toolkit[all]) (2022.11.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (3.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (2.23.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (2.1.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 69.3 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.1.0->nemo_toolkit[all]) (5.10.0)
# Collecting pip-api
#   Downloading pip_api-0.0.30-py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 66.0 MB/s
# Collecting pipreqs
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (3.19.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (3.4.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.50.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (2.14.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (3.2.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 53.5 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 70.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.0.1->nemo_toolkit[all]) (3.8.0)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.4 MB/s
# Collecting botocore<1.30.0,>=1.29.14
#   Downloading botocore-1.29.14-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 45.0 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 65.0 MB/s
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->nemo_toolkit[all]) (0.2.5)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      |████████████████████████████████| 180 kB 73.8 MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown->nemo_toolkit[all]) (4.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->nemo_toolkit[all]) (1.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.0.3)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (7.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.1.12)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.6.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 51.0 MB/s
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.16)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.11.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.15.0)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.11.3)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.0)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.6.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (23.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.19.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (0.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (3.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->nemo_toolkit[all]) (0.39.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->nemo_toolkit[all]) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->nemo_toolkit[all]) (2022.6)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from pip-api->isort[requirements]<5->nemo_toolkit[all]) (21.1.3)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Collecting simplejson>=3.8.1
#   Downloading simplejson-3.18.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 62.3 MB/s
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (0.8.10)
# Collecting pyannote.database>=4.0.1
#   Downloading pyannote.database-4.1.3-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 531 kB/s
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (1.7.1)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Collecting shellingham<2.0.0,>=1.3.0
#   Downloading shellingham-1.5.0-py2.py3-none-any.whl (9.3 kB)
# Collecting colorama<0.5.0,>=0.4.3
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting rich<13.0.0,>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 70.5 MB/s
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 7.6 MB/s
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (9.0.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->nemo_toolkit[all]) (1.7.1)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (500 kB)
#      |████████████████████████████████| 500 kB 66.6 MB/s
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (4.9.1)
# Collecting mecab-python3==1.0.5
#   Downloading mecab_python3-1.0.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (574 kB)
#      |████████████████████████████████| 574 kB 66.0 MB/s
# Collecting ipadic<2.0,>=1.0
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      |████████████████████████████████| 13.4 MB 56.8 MB/s
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.11.0)
# Requirement already satisfied: docutils<0.18,>=0.11 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.17.1)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.2.4)
# Collecting pybtex-docutils>=1.0.0
#   Downloading pybtex_docutils-1.0.2-py3-none-any.whl (6.3 kB)
# Collecting sphinx
#   Downloading sphinx-5.3.0-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 47.6 MB/s
# Collecting pybtex>=0.24
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      |████████████████████████████████| 561 kB 72.2 MB/s
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Collecting pygments
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 67.1 MB/s
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.0 MB/s
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 9.4 MB/s
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 72.3 MB/s
# Collecting jinja2<=3.0.0
#   Downloading Jinja2-3.0.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 58.1 MB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 11.9 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (5.4.8)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (2.3)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 71.0 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 74.4 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.0-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 75.3 MB/s
#   Downloading sentry_sdk-1.10.1-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 78.4 MB/s
#   Downloading sentry_sdk-1.10.0-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 55.5 MB/s
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 69.1 MB/s
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 72.6 MB/s
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 72.8 MB/s
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 68.8 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 69.8 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 39.1 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 73.8 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 70.8 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 78.7 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 80.6 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 80.6 MB/s
# Building wheels for collected packages: nemo-toolkit, future, antlr4-python3-runtime, sacremoses, fasttext, distance, kaldi-python-io, kaldiio, pesq, docopt, pystoi, ipadic, pathtools, wget
#   Building wheel for nemo-toolkit (setup.py) ... done
#   Created wheel for nemo-toolkit: filename=nemo_toolkit-1.7.0-py3-none-any.whl size=3163443 sha256=c2d99f96cfa111ec11eee399469c731ebbd8a41b095d5df60bbec020a2cf4388
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cs918cu5/wheels/29/3a/ce/9362ebc69aeccb842b28e564049f2f610610fb8d7f7e23c352
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491071 sha256=3a81e6c2ba2715d50bc7faf2be22cb608e24847faac705d42291d912dbddaf8a
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=35a83b5564127f5183045147fbff03d7b58211e11c990338326ac8ab6b3c0ae1
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=bb72964a25cd733dc38d6b55292f65ca8d96c5179a9d76979c7a8984688a2a61
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3157955 sha256=5afee4af0d4cd8bd1d2d731159eb367e8891de1df6300f2e734163609902b11d
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16275 sha256=2b54e9dfa38b49ae5b83681b2e378933b5db5c30bfeddbeb71c0624096d14bd5
#   Stored in directory: /root/.cache/pip/wheels/b2/10/1b/96fca621a1be378e2fe104cfb0d160bb6cdf3d04a3d35266cc
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.2.2-py3-none-any.whl size=8970 sha256=4608092c90417dd210fec24cb2d7461dc81b8d4a0e82eec43d66db5cc834e181
#   Stored in directory: /root/.cache/pip/wheels/a9/26/38/7678d1ff6cd1bbcbfc0d80b0a29d94d917dfa9ad790b4a85a9
#   Building wheel for kaldiio (setup.py) ... done
#   Created wheel for kaldiio: filename=kaldiio-2.17.2-py3-none-any.whl size=24471 sha256=2b2e4e53846fe1a9bae6d56fa71a76025872ed9eb31f013319e6744df246c13c
#   Stored in directory: /root/.cache/pip/wheels/04/07/e8/45641287c59bf6ce41e22259f8680b521c31e6306cb88392ac
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp37-cp37m-linux_x86_64.whl size=214598 sha256=b2053938d922e6672f57a111adfcdc4eb7d5973dff51e5e1db2a768351f7146a
#   Stored in directory: /root/.cache/pip/wheels/c5/3d/9c/542731f8357f7c82eb6ac2047cc5375f92c9a05b09a715aff6
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=c83c5767a48bee4eaf878fea37f8a7c733dba172ab97508f895b1bbb975aa170
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for pystoi (setup.py) ... done
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7792 sha256=ed36931225eaabb0408550699376f0fa95c20ff048101e0693a97fbd5bc3bda3
#   Stored in directory: /root/.cache/pip/wheels/46/4a/ad/3ab460193ed0535430b4b1575f255aa6bae69df17453628e86
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556723 sha256=38d5054ba38c8599c2bbb7b6c35583c36d18b6287ca2eb6052212b23e0785424
#   Stored in directory: /root/.cache/pip/wheels/33/8b/99/cf0d27191876637cd3639a560f93aa982d7855ce826c94348b
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=e435f2d869a8ee88ab5f25a38849d87e625018a0f688478a2a868d58bc22ff45
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=474fa7b054d18896986598b21d31860f1297fb9a37037d918b992d58a70de1c1
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built nemo-toolkit future antlr4-python3-runtime sacremoses fasttext distance kaldi-python-io kaldiio pesq docopt pystoi ipadic pathtools wget
# Installing collected packages: urllib3, setuptools, pygments, jedi, jinja2, commonmark, smmap, simplejson, shellingham, rich, pyyaml, latexcodec, jmespath, colorama, yarg, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, ruamel.yaml.clib, pybtex, pyannote.core, portalocker, gitdb, docopt, botocore, antlr4-python3-runtime, wget, unidecode, typed-ast, torchmetrics, tokenizers, sphinx, shortuuid, setproctitle, sentry-sdk, sacrebleu, s3transfer, ruamel.yaml, pyDeprecate, pybtex-docutils, pybind11, pyannote.database, pipreqs, pip-api, pathtools, pathspec, onnx, omegaconf, mecab-python3, isort, ipadic, huggingface-hub, GitPython, future, frozendict, docker-pycreds, distance, braceexpand, youtokentome, webdataset, wandb, transformers, torch-stft, sphinxcontrib-bibtex, sox, sentencepiece, sacremoses, rapidfuzz, pytorch-lightning, pytest-runner, pystoi, pypinyin, pydub, pyannote.metrics, pesq, parameterized, pangu, opencc, nemo-toolkit, kaldiio, kaldi-python-io, kaldi-io, hydra-core, g2p-en, ftfy, fasttext, boto3, black, attrdict
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.0.0 which is incompatible.
# Successfully installed GitPython-3.1.29 antlr4-python3-runtime-4.9.3 attrdict-2.0.1 black-19.10b0 boto3-1.26.14 botocore-1.29.14 braceexpand-0.1.7 colorama-0.4.6 commonmark-0.9.1 distance-0.1.3 docker-pycreds-0.4.0 docopt-0.6.2 fasttext-0.9.2 frozendict-2.3.4 ftfy-6.1.1 future-0.18.2 g2p-en-2.1.0 gitdb-4.0.9 huggingface-hub-0.11.0 hydra-core-1.2.0 ipadic-1.0.0 isort-4.3.21 jedi-0.18.2 jinja2-3.0.0 jmespath-1.0.1 kaldi-io-0.9.4 kaldi-python-io-1.2.2 kaldiio-2.17.2 latexcodec-2.0.1 mecab-python3-1.0.5 nemo-toolkit-1.7.0 omegaconf-2.2.3 onnx-1.12.0 opencc-1.1.4 pangu-4.0.6.1 parameterized-0.8.1 pathspec-0.10.2 pathtools-0.1.2 pesq-0.0.4 pip-api-0.0.30 pipreqs-0.4.11 portalocker-2.6.0 pyDeprecate-0.3.1 pyannote.core-4.5 pyannote.database-4.1.3 pyannote.metrics-3.2.1 pybind11-2.10.1 pybtex-0.24.0 pybtex-docutils-1.0.2 pydub-0.25.1 pygments-2.13.0 pypinyin-0.47.1 pystoi-0.3.3 pytest-runner-6.0.0 pytorch-lightning-1.5.10 pyyaml-5.4.1 rapidfuzz-2.13.2 rich-12.6.0 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7 s3transfer-0.6.0 sacrebleu-2.3.1 sacremoses-0.0.53 sentencepiece-0.1.97 sentry-sdk-1.9.0 setproctitle-1.3.2 setuptools-59.5.0 shellingham-1.5.0 shortuuid-1.0.11 simplejson-3.18.0 smmap-5.0.0 sox-1.4.1 sphinx-5.3.0 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-bibtex-2.5.0 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 tokenizers-0.13.2 torch-stft-0.1.4 torchmetrics-0.10.3 transformers-4.24.0 typed-ast-1.5.4 unidecode-1.3.6 urllib3-1.25.11 wandb-0.13.5 webdataset-0.1.62 wget-3.2 yarg-0.1.9 youtokentome-1.0.6

# %%
# !nvidia-smi -L # to know which gpu you are running on
# Out:
# GPU 0: Tesla T4 (UUID: GPU-92ba798a-30a5-2a91-567a-152bbd4310ed)

# %%
# !pip install nemo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo
#   Downloading NEMO-4.2.1-py36-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 4.7 MB/s
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.7/dist-packages (from nemo) (2.8.2)
# Collecting django-mptt==0.13.4
#   Downloading django_mptt-0.13.4-py3-none-any.whl (137 kB)
#      |████████████████████████████████| 137 kB 53.9 MB/s
# Collecting requests==2.28.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Collecting ldap3==2.9.1
#   Downloading ldap3-2.9.1-py2.py3-none-any.whl (432 kB)
#      |████████████████████████████████| 432 kB 65.6 MB/s
# Collecting django-filter==22.1
#   Downloading django_filter-22.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 11.0 MB/s
# Collecting djangorestframework==3.13.1
#   Downloading djangorestframework-3.13.1-py3-none-any.whl (958 kB)
#      |████████████████████████████████| 958 kB 40.3 MB/s
# Collecting drf-excel==2.1.0
#   Downloading drf_excel-2.1.0-py3-none-any.whl (13 kB)
# Collecting Pillow==9.2.0
#   Downloading Pillow-9.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 52.5 MB/s
# Collecting pymodbus==2.5.3
#   Downloading pymodbus-2.5.3-py2.py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 70.7 MB/s
# Collecting drf-flex-fields==1.0.0
#   Downloading drf-flex-fields-1.0.0.tar.gz (30 kB)
# Collecting cryptography==37.0.4
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 44.6 MB/s
# Collecting Django==3.2.15
#   Downloading Django-3.2.15-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 51.5 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography==37.0.4->nemo) (1.15.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from Django==3.2.15->nemo) (2022.6)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from Django==3.2.15->nemo) (0.4.3)
# Collecting asgiref<4,>=3.3.2
#   Downloading asgiref-3.5.2-py3-none-any.whl (22 kB)
# Collecting django-js-asset
#   Downloading django_js_asset-2.0.0-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: openpyxl>=2.4 in /usr/local/lib/python3.7/dist-packages (from drf-excel==2.1.0->nemo) (3.0.10)
# Requirement already satisfied: pyasn1>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from ldap3==2.9.1->nemo) (0.4.8)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from pymodbus==2.5.3->nemo) (1.15.0)
# Collecting pyserial>=3.4
#   Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 11.6 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests==2.28.1->nemo) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests==2.28.1->nemo) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests==2.28.1->nemo) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.28.1->nemo) (1.25.11)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->Django==3.2.15->nemo) (4.1.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography==37.0.4->nemo) (2.21)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.4->drf-excel==2.1.0->nemo) (1.1.0)
# Building wheels for collected packages: drf-flex-fields
#   Building wheel for drf-flex-fields (setup.py) ... done
#   Created wheel for drf-flex-fields: filename=drf_flex_fields-1.0.0-py3-none-any.whl size=15438 sha256=3ceb08ef3986639bc1351403215268b1b2aef496bda3b9333d41db6b98409201
#   Stored in directory: /root/.cache/pip/wheels/2e/78/48/ee06d07ed0e4b5ec89e82a7f8b24929e0685057c487041c4f7
# Successfully built drf-flex-fields
# Installing collected packages: asgiref, Django, pyserial, djangorestframework, django-js-asset, requests, pymodbus, Pillow, ldap3, drf-flex-fields, drf-excel, django-mptt, django-filter, cryptography, nemo
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed Django-3.2.15 Pillow-9.2.0 asgiref-3.5.2 cryptography-37.0.4 django-filter-22.1 django-js-asset-2.0.0 django-mptt-0.13.4 djangorestframework-3.13.1 drf-excel-2.1.0 drf-flex-fields-1.0.0 ldap3-2.9.1 nemo-4.2.1 pymodbus-2.5.3 pyserial-3.5 requests-2.28.1

# %%
# Import NeMo and it's ASR, NLP and TTS collections
import nemo
# Import Speech Recognition collection
import nemo.collections.asr as nemo_asr
# Import Natural Language Processing colleciton
import nemo.collections.nlp as nemo_nlp
# Import Speech Synthesis collection
import nemo.collections.tts as nemo_tts
# We'll use this to listen to audio
import IPython
# Out:
# [NeMo W 2022-11-22 16:31:04 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################
#
# [NeMo W 2022-11-22 16:31:06 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/jit/annotations.py:296: UserWarning: TorchScript will treat type annotations of Tensor dtype-specific subtypes as if they are normal Tensors. dtype constraints are not enforced in compilation either.
#       warnings.warn("TorchScript will treat type annotations of Tensor "
#
# [NeMo W 2022-11-22 16:31:08 experimental:28] Module <class 'nemo.collections.nlp.data.language_modeling.megatron.megatron_batch_samplers.MegatronPretrainingRandomBatchSampler'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-11-22 16:31:09 experimental:28] Module <class 'nemo.collections.nlp.models.text_normalization_as_tagging.thutmose_tagger.ThutmoseTaggerModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-11-22 16:31:09 experimental:28] Module <class 'nemo.collections.common.tokenizers.text_to_speech.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-11-22 16:31:09 experimental:28] Module <class 'nemo.collections.tts.models.radtts.RadTTSModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.

# %%
"""
You can run either this notebook locally (if you have all the dependencies and a GPU) or on Google Colab.

Instructions for setting up Colab are as follows:
1. Open a new Python 3 notebook.
2. Import this notebook from GitHub (File -> Upload Notebook -> "GITHUB" tab -> copy/paste GitHub URL)
3. Connect to an instance with a GPU (Runtime -> Change runtime type -> select "GPU" for hardware accelerator)
4. Run this cell to set up dependencies.
5. Restart the runtime (Runtime -> Restart Runtime) for any upgraded packages to take effect
"""
# If you're using Google Colab and not running locally, run this cell.

## Install dependencies
# !pip install wget
# !apt-get install sox libsndfile1 ffmpeg
# !pip install text-unidecode
# !pip install matplotlib>=3.3.2

## Install NeMo
BRANCH = 'main'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]

"""
Remember to restart the runtime for the kernel to pick up any upgraded packages (e.g. matplotlib)!
Alternatively, you can uncomment the exit() below to crash and restart the kernel, in the case
that you want to use the "Run All Cells" (or similar) option.
"""
# exit()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (3.2)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-4ubuntu0.18.04.2).
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 5 not upgraded.
# Need to get 760 kB of archives.
# After this operation, 6,717 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrwb0 amd64 0.1.3-2.1 [45.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox3 amd64 14.4.2-3ubuntu0.18.04.1 [226 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2-3ubuntu0.18.04.1 [10.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-base amd64 14.4.2-3ubuntu0.18.04.1 [32.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 sox amd64 14.4.2-3ubuntu0.18.04.1 [101 kB]
# Fetched 760 kB in 2s (405 kB/s)
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 123991 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../2-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../3-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../4-libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../5-libsox-fmt-alsa_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../6-libsox-fmt-base_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../7-sox_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking sox (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up sox (14.4.2-3ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.7/dist-packages (1.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-b925jhtw/nemo-toolkit_93860ea317554ec88c49b4f3889d9fec
#   Running command git clone -q https://github.com/NVIDIA/NeMo.git /tmp/pip-install-b925jhtw/nemo-toolkit_93860ea317554ec88c49b4f3889d9fec
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.56.4)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.21.6)
# Requirement already satisfied: onnx>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.12.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.17.21)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: setuptools==59.5.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (59.5.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.9.1)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.12.1+cu113)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.64.1)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.14.1)
# Requirement already satisfied: black==19.10b0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (19.10b0)
# Collecting click==8.0.2
#   Downloading click-8.0.2-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 7.5 MB/s
# Requirement already satisfied: isort[requirements]<5 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.3.21)
# Requirement already satisfied: parameterized in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.6.4)
# Requirement already satisfied: pytest-runner in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (6.0.0)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (5.3.0)
# Requirement already satisfied: sphinxcontrib-bibtex in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.5.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.13.5)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2022.6.2)
# Requirement already satisfied: hydra-core<1.3,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: omegaconf<2.3,>=2.2 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.2.3)
# Collecting pytorch-lightning<1.8,>=1.7.0
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
#      |████████████████████████████████| 708 kB 50.8 MB/s
# Requirement already satisfied: pyyaml<6 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (5.4.1)
# Requirement already satisfied: torchmetrics>=0.4.1rc0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.10.3)
# Collecting transformers<=4.21.2,>=4.0.1
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 61.4 MB/s
# Requirement already satisfied: webdataset<=0.1.62,>=0.1.48 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.1.62)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3.5)
# Requirement already satisfied: sacremoses>=0.0.43 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.0.53)
# Requirement already satisfied: sentencepiece<1.0.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.1.97)
# Requirement already satisfied: youtokentome>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.0.6)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.1.7)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.5.3)
# Requirement already satisfied: g2p_en in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.7.1)
# Requirement already satisfied: kaldi-python-io in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.2.2)
# Requirement already satisfied: kaldiio in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.17.2)
# Collecting librosa>=0.9.0
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      |████████████████████████████████| 214 kB 69.8 MB/s
# Requirement already satisfied: marshmallow in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.19.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (21.3)
# Requirement already satisfied: pyannote.core in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.5)
# Requirement already satisfied: pyannote.metrics in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.25.1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.7.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: sox in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.4.1)
# Collecting texterrors
#   Downloading texterrors-0.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 62.1 MB/s
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.26.14)
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 556 kB/s
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      |████████████████████████████████| 17.0 MB 61.2 MB/s
# Requirement already satisfied: fasttext in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.9.2)
# Collecting flask_restful
#   Downloading Flask_RESTful-0.3.9-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (6.1.1)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.4.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.1.0)
# Collecting ijson
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 73.5 MB/s
# Requirement already satisfied: jieba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.42.1)
# Collecting matplotlib>=3.3.2
#   Using cached matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.7)
# Requirement already satisfied: opencc in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.1.4)
# Requirement already satisfied: pangu in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.0.6.1)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.13.2)
# Requirement already satisfied: sacrebleu[ja] in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.3.1)
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 6.1 MB/s
# Requirement already satisfied: attrdict in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: pesq in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.0.4)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.47.1)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.3.3)
# Collecting jiwer>=2.0.0
#   Downloading jiwer-2.5.1-py3-none-any.whl (15 kB)
# Collecting progress>=1.5
#   Downloading progress-1.6.tar.gz (7.8 kB)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.8.10)
# Collecting textdistance>=4.1.5
#   Downloading textdistance-4.5.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: pathspec<1,>=0.6 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: typed-ast>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.5.4)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (22.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click==8.0.2->nemo_toolkit[all]) (4.13.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core<1.3,>=1.2.0->nemo_toolkit[all]) (5.10.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.7/dist-packages (from hydra-core<1.3,>=1.2.0->nemo_toolkit[all]) (4.9.3)
# Requirement already satisfied: pipreqs in /usr/local/lib/python3.7/dist-packages (from isort[requirements]<5->nemo_toolkit[all]) (0.4.11)
# Requirement already satisfied: pip-api in /usr/local/lib/python3.7/dist-packages (from isort[requirements]<5->nemo_toolkit[all]) (0.0.30)
# Collecting levenshtein==0.20.2
#   Downloading Levenshtein-0.20.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 71.4 MB/s
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.1.1)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (3.19.6)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (2022.11.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (0.3.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (3.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (2.23.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (6.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (2.14.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (1.50.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click==8.0.2->nemo_toolkit[all]) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<=4.21.2,>=4.0.1->nemo_toolkit[all]) (3.8.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 56.7 MB/s
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from boto3->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.14 in /usr/local/lib/python3.7/dist-packages (from boto3->nemo_toolkit[all]) (1.29.14)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext->nemo_toolkit[all]) (2.10.1)
# Collecting aniso8601>=0.82
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (1.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (2022.6)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (1.1.0)
# Collecting Flask>=0.8
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 12.4 MB/s
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (3.0.0)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 77.5 MB/s
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=3.0->Flask>=0.8->flask_restful->nemo_toolkit[all]) (2.0.1)
# Collecting MarkupSafe>=2.0.0rc2
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->nemo_toolkit[all]) (0.2.5)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from g2p_en->nemo_toolkit[all]) (0.1.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown->nemo_toolkit[all]) (4.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->nemo_toolkit[all]) (1.5.2)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.3.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.0.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (7.9.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.18.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.13.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.16)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (23.2.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.11.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.15.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.0)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.6.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.16.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.19.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (3.0.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (0.4.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->nemo_toolkit[all]) (0.39.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->nemo_toolkit[all]) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from pip-api->isort[requirements]<5->nemo_toolkit[all]) (21.1.3)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from pipreqs->isort[requirements]<5->nemo_toolkit[all]) (0.6.2)
# Requirement already satisfied: yarg in /usr/local/lib/python3.7/dist-packages (from pipreqs->isort[requirements]<5->nemo_toolkit[all]) (0.1.9)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: simplejson>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.core->nemo_toolkit[all]) (3.18.0)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (1.7.1)
# Requirement already satisfied: pyannote.database>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (4.1.3)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.7/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: rich<13.0.0,>=10.11.0 in /usr/local/lib/python3.7/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (12.6.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.9.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (9.0.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.8,>=1.7.0->nemo_toolkit[all]) (1.7.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml->nemo_toolkit[all]) (0.2.7)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (4.9.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (2.6.0)
# Requirement already satisfied: mecab-python3==1.0.5 in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (1.0.5)
# Requirement already satisfied: ipadic<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers->nemo_toolkit[all]) (0.13.1+cu113)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: docutils<0.20,>=0.14 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.17.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.11.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: pybtex-docutils>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: pybtex>=0.24 in /usr/local/lib/python3.7/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (0.24.0)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from pybtex>=0.24->sphinxcontrib-bibtex->nemo_toolkit[all]) (2.0.1)
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.8 MB/s
# Collecting plac
#   Downloading plac-1.3.5-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from texterrors->nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers->nemo_toolkit[all]) (7.1.2)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (1.9.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (1.0.11)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (5.4.8)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (3.1.29)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (0.4.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (2.3)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (1.3.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb->nemo_toolkit[all]) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->nemo_toolkit[all]) (5.0.0)
# Building wheels for collected packages: nemo-toolkit, progress, sentence-transformers
#   Building wheel for nemo-toolkit (setup.py) ... done
#   Created wheel for nemo-toolkit: filename=nemo_toolkit-1.13.0rc0-py3-none-any.whl size=4188044 sha256=0888dd548f435f55e77ccbe835b93ad197961df168ce3e0562b56b3b5a5f6ba4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-envf1rnk/wheels/82/66/ef/7248c1c27216d06425cab14b3391059534c889aaf2db89b855
#   Building wheel for progress (setup.py) ... done
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9630 sha256=bcfd9073ff3627ca37462d4fb9bef6d15b8d0e23cd641616aa877f8fc6b84189
#   Stored in directory: /root/.cache/pip/wheels/8e/d7/61/498d8e27dc11e9805b01eb3539e2ee344436fc226daeb5fe87
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=8137d84ab152e5d7ee161b1d335374a1b7860765ef37be67c34a7ec32f5a46e8
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built nemo-toolkit progress sentence-transformers
# Installing collected packages: MarkupSafe, click, werkzeug, tokenizers, itsdangerous, transformers, plac, loguru, levenshtein, Flask, aniso8601, texterrors, textdistance, sentence-transformers, pytorch-lightning, progress, nemo-toolkit, jiwer, ijson, flask-restful, faiss-cpu, einops
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.2
#     Uninstalling tokenizers-0.13.2:
#       Successfully uninstalled tokenizers-0.13.2
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.24.0
#     Uninstalling transformers-4.24.0:
#       Successfully uninstalled transformers-4.24.0
#   Attempting uninstall: Flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 1.5.10
#     Uninstalling pytorch-lightning-1.5.10:
#       Successfully uninstalled pytorch-lightning-1.5.10
#   Attempting uninstall: nemo-toolkit
#     Found existing installation: nemo-toolkit 1.7.0
#     Uninstalling nemo-toolkit-1.7.0:
#       Successfully uninstalled nemo-toolkit-1.7.0
# Successfully installed Flask-2.2.2 MarkupSafe-2.1.1 aniso8601-9.0.1 click-8.0.2 einops-0.6.0 faiss-cpu-1.7.3 flask-restful-0.3.9 ijson-3.1.4 itsdangerous-2.1.2 jiwer-2.5.1 levenshtein-0.20.2 loguru-0.6.0 nemo-toolkit-1.13.0rc0 plac-1.3.5 progress-1.6 pytorch-lightning-1.7.7 sentence-transformers-2.2.2 textdistance-4.5.0 texterrors-0.4.4 tokenizers-0.12.1 transformers-4.21.2 werkzeug-2.2.2
# '\nRemember to restart the runtime for the kernel to pick up any upgraded packages (e.g. matplotlib)!\nAlternatively, you can uncomment the exit() below to crash and restart the kernel, in the case\nthat you want to use the "Run All Cells" (or similar) option.\n'

# %%
import os
# This is where the an4/ directory will be placed.
# Change this if you don't want the data to be extracted in the current directory.
data_dir = '.'

if not os.path.exists(data_dir):
  os.makedirs(data_dir)

# %%
import glob
import os
import subprocess
import tarfile
import wget

# Download the dataset. This will take a few moments...
print("******")
if not os.path.exists(data_dir + '/an4_sphere.tar.gz'):
    an4_url = 'https://dldata-public.s3.us-east-2.amazonaws.com/an4_sphere.tar.gz'  # for the original source, please visit http://www.speech.cs.cmu.edu/databases/an4/an4_sphere.tar.gz 
    an4_path = wget.download(an4_url, data_dir)
    print(f"Dataset downloaded at: {an4_path}")
else:
    print("Tarfile already exists.")
    an4_path = data_dir + '/an4_sphere.tar.gz'

if not os.path.exists(data_dir + '/an4/'):
    # Untar and convert .sph to .wav (using sox)
    tar = tarfile.open(an4_path)
    tar.extractall(path=data_dir)

    print("Converting .sph to .wav...")
    sph_list = glob.glob(data_dir + '/an4/**/*.sph', recursive=True)
    for sph_path in sph_list:
        wav_path = sph_path[:-4] + '.wav'
        cmd = ["sox", sph_path, wav_path]
        subprocess.run(cmd)
print("Finished conversion.\n******")

import librosa
import IPython.display as ipd

# Load and listen to the audio file
example_file = data_dir + '/an4/wav/an4_clstk/mgah/cen2-mgah-b.wav'
audio, sample_rate = librosa.load(example_file)

ipd.Audio(example_file, rate=sample_rate)
# Out:
# ******
# Dataset downloaded at: ./an4_sphere.tar.gz
# Converting .sph to .wav...
# Finished conversion.
# ******
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib inline
import librosa.display
import matplotlib.pyplot as plt

# Plot our example audio file's waveform
plt.rcParams['figure.figsize'] = (15,7)
plt.title('Waveform of Audio Example')
plt.ylabel('Amplitude')

_ = librosa.display.waveshow(audio)

# %%
import numpy as np

# Get spectrogram using Librosa's Short-Time Fourier Transform (stft)
spec = np.abs(librosa.stft(audio))
spec_db = librosa.amplitude_to_db(spec, ref=np.max)  # Decibels

# Use log scale to view frequencies
librosa.display.specshow(spec_db, y_axis='log', x_axis='time')
plt.colorbar()
plt.title('Audio Spectrogram');

# %%
# Plot the mel spectrogram of our sample
mel_spec = librosa.feature.melspectrogram(audio, sr=sample_rate)
mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

librosa.display.specshow(
    mel_spec_db, x_axis='time', y_axis='mel')
plt.colorbar()
plt.title('Mel Spectrogram');

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.1.1)

# %%
# This line will download pre-trained QuartzNet15x5 model from NVIDIA's NGC cloud and instantiate it for you
quartznet = nemo_asr.models.EncDecCTCModel.from_pretrained(model_name="QuartzNet15x5Base-En")
# Out:
# [NeMo I 2022-11-22 16:37:03 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemospeechmodels/versions/1.0.0a5/files/QuartzNet15x5Base-En.nemo to /root/.cache/torch/NeMo/NeMo_1.13.0rc0/QuartzNet15x5Base-En/2b066be39e9294d7100fb176ec817722/QuartzNet15x5Base-En.nemo
# [NeMo I 2022-11-22 16:37:12 common:912] Instantiating model from pre-trained checkpoint
# [NeMo I 2022-11-22 16:37:13 features:225] PADDING: 16
# [NeMo I 2022-11-22 16:37:14 audio_preprocessing:495] Numba CUDA SpecAugment kernel is being used
# [NeMo I 2022-11-22 16:37:22 save_restore_connector:243] Model EncDecCTCModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.13.0rc0/QuartzNet15x5Base-En/2b066be39e9294d7100fb176ec817722/QuartzNet15x5Base-En.nemo.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
files = [os.path.join(data_dir, '/content/drive/My Drive/Speech/singleaudio.wav')]
for fname, transcription in zip(files, quartznet.transcribe(paths2audio_files=files)):
  print(f"Audio in {fname} was recognized as: {transcription}")
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Audio in /content/drive/My Drive/Speech/singleaudio.wav was recognized as: carcula salamatakanuguti conda madicadi condatoka chukodi con salubunda elugu kundam kerikapena pandicondu konda mosaloni mata sidugugundam batsala matakanuguti salama chenchubunda gadimitabo netipenta nalamalayaa saga banda kraa balisa kondu vo tukuntabord viavasaa bomulu murikimalla sarre votukunta alucula sellartham babi kontapeda jana conda yerra condatoka upulagundi at the muguri chintala hallaquaya county rai saririvasaa bumuluupulagandi votikunda hustalap aya conductor to salama ustalapaa ko basawaya gundi garnipenta condacacula sella mocalloni krawa wutalapa nerupare kondafole ramaguri bakaavalakonda panuku laguboka et thamasswami irudus wami chinabawi nelubare konda modula sari sudebo kalabavi chukodi conda panticonda neturi bundle biludani morasa chitumitupa parakabawi zu babi chintalamata parakabawi kala konda yara sari sallu bunda barpani conda pulichintelaconda gud unomoconda kuka dona biji mata nerid chetu conda angenea swarmi goodi selama lambardidani matayalagaje tu konmodula sarri nemilikonda
